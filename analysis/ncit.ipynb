# %%
import owlready2 as owl
ncit = owl.get_ontology('../data/ncit/ncit_20.09d.owl')
ncit.load()
graph = owl.default_world.as_rdflib_graph()
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
# get_ontology("http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#")

# %%
# get all classes with Semantic_Type = "Pharmacologic Substance"
query_str = """SELECT ?x WHERE {?x <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#P106> "Pharmacologic Substance" }"""
results = set(graph.query(query_str))

def parse_uri(uri):
    uri.toPython().split('#')[1]

semtype_ps = set()
for r in results:
    semtype_ps.add(ncit[parse_uri(r[0])])

# %%
# get all classes that are descendants of C1909 ("Pharmacologic Substance")
def build_descendants(node, descendants):
    children = node.descendants()
    if len(children) == 0:
        raise Exception(children)
    elif len(children) == 1:
        descendants.add(node)
    else:
        for child in children:
            if child.name != node.name:
                build_descendants(child, descendants)

descendants = set()
build_descendants(ncit.C1909, descendants)

# %%
semtype_not_desc = semtype_ps - descendants
desc_not_semtype = descendants - semtype_ps
print(f"# of common elements: {len(semtype_ps.intersection(descendants))}")
print(f"# of elements with semantic type but not in descendants: {len(semtype_not_desc)}")
print(f"# of elements in descendant but don't have semantic type: {len(desc_not_semtype)}")
# Out:
# # of common elements: 15512
# # of elements with semantic type but not in descendants: 1637
# # of elements in descendant but don't have semantic type: 2954

# %%
def print_info(owl_class):
    if owl_class.P107:
        name = owl_class.P107
    elif owl_class.P108:
        name = owl_class.P108
    elif owl_class.P90:
        name = owl_class.P90[0]
    print(f"{name} {owl_class.NHC0}")

# %%
# 
list(map(print_info, semtype_not_desc))
# Out:
# ['Pyran Polymer'] ['C29343']
# ['Amifampridine'] ['C87424']
# ['d-Alpha-Tocopherol'] ['C2832']
# ['Soy Isoflavones'] ['C65152']
# ['Propisergide'] ['C66490']
# ['Etanidazole'] ['C1092']
# ['Levomenol'] ['C80904']
# ['Magnesium Malate'] ['C87336']
# ['Aluminum Sesquichlorohydrate'] ['C142918']
# ['Copal'] ['C74358']
# ['Quercetin'] ['C792']
# ['Cathepsin-Activatable Cy5 Fluorescent Imaging Probe LUM015'] ['C105147']
# ['Anti-CD38 Monoclonal Antibody'] ['C155321']
# ['Alpha-Tocopherol'] ['C74960']
# ['PS IL-10/Placebo'] ['C29336']
# ['Sodium Ferulate'] ['C84155']
# ['DOTMP'] ['C1496']
# ['Bisbentiamine'] ['C81630']
# ['Elm'] ['C65510']
# ['Paricalcitol'] ['C38693']
# ['Rutin'] ['C819']
# ['Dendritic Cell Vaccine'] ['C28310']
# ['ALVAC-CEA Vaccine'] ['C1648']
# ['Coniine Hydrochloride'] ['C87478']
# ['dl-alpha-Tocopherol'] ['C74578']
# ['Ferric Phosphate'] ['C83714']
# ['Probiotic Acidophilus'] ['C79797']
# ['Starch, Rice'] ['C80780']
# ['Telomerase:540-548 Peptide'] ['C2813']
# ['Visilizumab'] ['C2687']
# ['OPCs/Green Tea/Spirullina/Curcumin/Antrodia Camphorate/Fermented Soymilk Extract Capsule'] ['C90545']
# ['Bentiamine'] ['C77084']
# ['Caseinate Protein Isolate'] ['C53440']
# ['Levonorgestrel-Releasing Intrauterine System'] ['C52193']
# ['Recombinant Interleukin-6'] ['C591']
# ['Red Tomato Juice'] ['C116328']
# ['Doconexent'] ['C68346']
# ['Ofranergene obadenovec'] ['C116893']
# ['Nefludan'] ['C29284']
# ['Huang Qi'] ['C129582']
# ['Recombinant Hematopoietic Growth Factor'] ['C2395']
# ['Benzquercin'] ['C74267']
# ['MOv-PBL Vaccine'] ['C2781']
# ['Gluten-free Compact Nutritional Supplement Drink'] ['C120033']
# ['Zinc Caprylate'] ['C84246']
# ['Menadiol Bis(Dihydrogen Phosphate)'] ['C80887']
# ['Binetrakin'] ['C90962']
# ['VEGFR-targeting Agent'] ['C163953']
# ['MUC1 Peptide Vaccine Formulation'] ['C67501']
# ['Cyanoglycoside Agent'] ['C29724']
# ['Krypton Kr-81m'] ['C76281']
# ['Fazarabine'] ['C1096']
# ['Recombinant Colony Stimulating Factor'] ['C387']
# ['Pegdarbepoetin Beta'] ['C174898']
# ['Activated Charcoal'] ['C77524']
# ['Acedoben'] ['C74109']
# ['Sodium Ascorbyl Phosphate'] ['C87289']
# ['Folescutol'] ['C65744']
# ['Croscarmellose Sodium'] ['C80923']
# ['Epidiferphane'] ['C165557']
# ['Paclitaxel Poliglumex'] ['C1795']
# ['Platelets Additive Solution'] ['C133336']
# ['Albumin (Human)'] ['C65218']
# ['Halofuginone'] ['C1120']
# ['Lodenosine'] ['C2755']
# ['Starch, Wheat'] ['C80782']
# ['High-Selenium Brassica juncea'] ['C71154']
# ['Anti-VEGF Monoclonal Antibody'] ['C2496']
# ['Sodium Perborate'] ['C84164']
# ['5-HP'] ['C28787']
# ['Deferitrin'] ['C76597']
# ['Antineoplastic Biological Agent'] ['C129821']
# ['Indole-3-Carbinol/Calcium/Schizandra/Vitamin D3/Milk Thistle/Stinging Nettle/Lignan-Based Nutritional Capsule'] ['C90584']
# ['Recombinant Interleukin'] ['C593']
# ['Oprelvekin'] ['C1722']
# ['Ingenol Mebutate'] ['C81553']
# ['Seocalcitol'] ['C26669']
# ['Hypromelloses'] ['C80902']
# ['Epoetin Alfa'] ['C2695']
# ['Convalescent Plasma'] ['C173750']
# ['Orantinib'] ['C1884']
# ['Pan-IDH Mutant Inhibitor AG-881'] ['C122874']
# ['Anhydrous Dextrose'] ['C61716']
# ['Micronutrient-Fortified Probiotic Yogurt'] ['C70677']
# ['Pentetic Acid Calcium'] ['C1710']
# ['Phsap'] ['C29323']
# ['Anti-CD33 Antibody-drug Conjugate'] ['C2333']
# ['Estrogens, Conjugated'] ['C482']
# ['2-(Diethylamino)ethanol'] ['C61620']
# ['Istiratumab'] ['C170084']
# ['Lactobacillus Fermented Extract'] ['C74053']
# ['Sulbutiamine'] ['C152450']
# ['Zolbetuximab'] ['C152960']
# ['Polydextrose'] ['C81624']
# ['Cardamom'] ['C74464']
# ['Antimony Triiodide'] ['C87427']
# ['Tasonermin'] ['C134821']
# ['D-Phenylalanine'] ['C61715']
# ['Phenolphthalein'] ['C29359']
# ['Therapeutic Estradiol'] ['C478']
# ['Pharmacologic Substance'] ['C1909']
# ['Cobalamin'] ['C939']
# ['Ellagic Acid'] ['C63641']
# ['Ferric Ammonium Ferrocyanide'] ['C87379']
# ['Rebimastat'] ['C1875']
# ['Pelitinib'] ['C73328']
# ['Permethrin'] ['C29354']
# ['Ranibizumab'] ['C67562']
# ['Clorophene'] ['C65342']
# ['Recombinant Tumor Necrosis Factor Family Protein'] ['C1941']
# ['Gallium Cation GA-67'] ['C92220']
# ['Cesium Cs 137'] ['C68812']
# ['Cyanocobalamin'] ['C64333']
# ['Tiomolibdic Acid'] ['C90831']
# ['Sodium Metabisulfite'] ['C77498']
# ['Bovine Serum Albumin'] ['C85253']
# ['Trilisate'] ['C29521']
# ['Radioactive Element'] ['C465']
# ['Cobalt Co-60'] ['C28239']
# ['Smoothened Antagonist'] ['C155725']
# ['Recombinant Interferon'] ['C584']
# ['Menadione'] ['C66086']
# ['Finished Pharmaceutical Product'] ['C42639']
# ['Povidone K29/32'] ['C82261']
# ['4-Fluoro-3-Nitroflavone'] ['C63941']
# ['Cyclamic Acid'] ['C76514']
# ['Melengesterol'] ['C29191']
# ['Recreational Drug'] ['C84368']
# ['Phenylmercuric Chloride'] ['C84051']
# ['Zinc Chloride'] ['C29865']
# ['Murine Monoclonal Antibody (LYM-1)'] ['C29236']
# ['HER2 Inhibitor'] ['C159156']
# ['Generic Drug'] ['C1312']
# ['Thiamine Hydrochloride'] ['C48025']
# ['Hydrastine'] ['C76031']
# ['Alpha 1 Antitrypsin'] ['C99638']
# ['ALVAC Vaccine'] ['C1479']
# ['SARS-CoV-2 mRNA Vaccine BNT162'] ['C173020']
# ['Bentonite'] ['C80916']
# ['Lactobacillus plantarum strain 299'] ['C90550']
# ['1,4-Phenylenebis(Methylene)Selenocyanate'] ['C63646']
# ['Magnesium Chloride'] ['C29240']
# ['Pibrozelesin'] ['C73263']
# ['Attenuated Live Virus Vaccine'] ['C1920']
# ['Aconitine'] ['C87421']
# ['Conessine Hydrobromide'] ['C79872']
# ['Immunoconjugate'] ['C1512']
# ['Ketorfanol'] ['C66000']
# ['Temsirolimus'] ['C1844']
# ['Therapeutic Glucocorticoid'] ['C521']
# ['Ropidoxuridine'] ['C76918']
# ['Propiolactone'] ['C44339']
# ['IDH2 inhibitor'] ['C168619']
# ['Chromium Picolinate'] ['C28931']
# ['Xylitol'] ['C76517']
# ['Betamipron'] ['C72565']
# ['Picrotoxinin'] ['C87770']
# ['Arugula Seed Powder'] ['C131020']
# ['Eriodictyon californicum Leaf'] ['C65528']
# ['Opium Tincture'] ['C29300']
# ['Pyridoxal'] ['C85248']
# ['Fowlpox Virus Vaccine'] ['C2521']
# ['Recombinant Tumor Necrosis Factor-Alpha'] ['C913']
# ['Psyllium'] ['C29393']
# ['Propiolactone'] ['C66485']
# ['Fructooligosaccharide Supplement'] ['C128561']
# ['Polysorbate 21'] ['C82649']
# ['Bifidobacterium lactis/Lactobacillus acidophilus/Inulin Probiotic Supplement'] ['C148481']
# ['Egtazic Acid'] ['C72097']
# ['Hexylene Glycol'] ['C77469']
# ['Methyl Methacrylate'] ['C47615']
# ['Levocarnitine'] ['C26657']
# ['Tumor Necrosis Factor (GEN)'] ['C2245']
# ['Gentian Violet'] ['C61776']
# ['EBV-specific Cytotoxic T-lymphocytes'] ['C23850']
# ['Cathepsin-cleavable NIR Substrate Probe 6QC-NIR'] ['C167240']
# ['Human Cells, Tissues, and Cellular and Tissue-Based Products from Cardiac Tissue'] ['C133362']
# ['Dimethylmercury'] ['C87485']
# ['SPI-77'] ['C29436']
# ['Mutated Ras Peptide'] ['C2730']
# ['Inactivated Vaccine'] ['C29694']
# ['Mercaptopurine'] ['C195']
# ['Sagopilone'] ['C80062']
# ['Lawsonia inermis-based Supplement'] ['C116859']
# ['Guanidinium Cation'] ['C1375']
# ['Recombinant Neurotrophins'] ['C1396']
# ['Fludarabine Phosphate'] ['C1102']
# ['Doretinel'] ['C77396']
# ['Pyridoxine'] ['C62619']
# ['Lanthanum'] ['C61800']
# ['FGFR-targeting Agent'] ['C164035']
# ['Vecabrutinib'] ['C136416']
# ['Magnesium Aspartate'] ['C76080']
# ['Sodium Cyclamate'] ['C84153']
# ['COVID-19 Vaccine'] ['C173023']
# ['BET Inhibitor'] ['C128462']
# ['Mannose, D-'] ['C83903']
# ['Trientine'] ['C66633']
# ['Potassium Bicarbonate'] ['C80938']
# ['Directly Observed Therapy'] ['C102624']
# ['GM-CSF cDNA/Gold Complex'] ['C2756']
# ['Eprodisate Disodium'] ['C65520']
# ['Magnesium Citrate'] ['C29241']
# ['Everolimus/Gefitinib'] ['C48388']
# ['DL-Tyrosine'] ['C61997']
# ['FGFR Inhibitor'] ['C155727']
# ['Gamma-delta Tocotrienol'] ['C101517']
# ['CD4+ CD25+ Regulatory T Cells'] ['C78829']
# ['Conjugated Monoclonal Antibody CC49'] ['C2747']
# ['Kaolin'] ['C80285']
# ['Phosphoric Acid'] ['C47670']
# ['Indibulin'] ['C74045']
# ['Stannous Chloride Anhydrous'] ['C77505']
# ['Cetyl Alcohol'] ['C47442']
# ['Glycosylated Recombinant Human G-CSF AVI-014'] ['C74520']
# ['MS-275'] ['C2724']
# ['Iodine I 124'] ['C64624']
# ['Apricoxib'] ['C77550']
# ['1,9-Nonanediol'] ['C28777']
# ['Whole Cell Vaccine'] ['C28309']
# ['5-Hydroxytryptophan, DL-'] ['C61712']
# ['Aminobenzoic Acid'] ['C61634']
# ['L-Lysine'] ['C95739']
# ['Ammonium Lauryl Sulfate'] ['C76699']
# ['BVCPP'] ['C28856']
# ['Turpentine'] ['C84233']
# ['Sodium Selenite Pentahydate'] ['C87347']
# ['Juven'] ['C26656']
# ['Ecogramostim'] ['C166486']
# ['Trisalicylate'] ['C29524']
# ['Succimer'] ['C61953']
# ['Lenograstim'] ['C49234']
# ['Potassium Bromide'] ['C76725']
# ['Antibacterial Agent'] ['C52588']
# ['SCAB'] ['C29419']
# ['Titanium Dioxide'] ['C61975']
# ['Yeast'] ['C66676']
# ['Stearalkonium Chloride'] ['C77507']
# ['ESO-1 Peptide Vaccine'] ['C2612']
# ['Dendritic Cell Tumor Peptide Vaccine'] ['C1987']
# ['Creatine Monohydrate'] ['C28945']
# ['Fowlpox Virus Vaccine Vector'] ['C48390']
# ['Tirapazamine'] ['C1464']
# ['Ferrous Carbonate'] ['C82285']
# ['Ferrous Gluconate'] ['C29048']
# ['Therapeutic Estetrol'] ['C68928']
# ['Acetomenaphthone'] ['C80886']
# ['Ether'] ['C29819']
# ['HDAC Inhibitor CHR-2845'] ['C82690']
# ['Fermented Prebiotic Dietary Supplement AferBio'] ['C156736']
# ['Monoclonal Antibody 2A11'] ['C29211']
# ['Ferrous Sulfate'] ['C29049']
# ['Selenious Acid'] ['C87344']
# ['Orotic Acid'] ['C81628']
# ['N-Acetyl-Alpha-D-Glucosamine'] ['C77375']
# ['Domiphen'] ['C83684']
# ['Sorbitol'] ['C29462']
# ['Maltitol'] ['C77138']
# ['1,25-Dihydroxy-16-ene-Vitamin D3'] ['C63738']
# ['Magnesium Sulfate Anhydrous'] ['C66051']
# ['Hydrofluoric Acid'] ['C82286']
# ['Pentetic Acid'] ['C460']
# ['Buffered Intrathecal Electrolyte/Dextrose Injection'] ['C2751']
# ['Rhenium Re 186'] ['C132280']
# ['Dendrobium Huoshanense Granules'] ['C173700']
# ['Transferrin-CRM107 '] ['C26676']
# ['Broxuridine'] ['C318']
# ['Tomato-Soy Juice'] ['C88300']
# ['Denatonium'] ['C83659']
# ['Irritumomab tiuxetan'] ['C29132']
# ['Gusperimus Trihydrochloride'] ['C1597']
# ['Salvia Officinalis Extract'] ['C71519']
# ['Sodium Monofluorophosphate'] ['C61945']
# ['Rapid-onset Opioid'] ['C93258']
# ['Menadiol Sodium Diphosphate'] ['C66084']
# ['Muramyl Tripeptide Phosphatidylethanolamine Liposome'] ['C2375']
# ['Pseudomonas Exotoxin Immunoconjugate'] ['C78532']
# ['Potassium Hydroxide'] ['C28204']
# ['Platinum Doublet'] ['C162261']
# ['PIXY'] ['C29326']
# ['Curcumin/Green Tea Extract/Polygonum cuspidatum Extract/Soybean Extract Capsule'] ['C78849']
# ['Rhubarb'] ['C74269']
# ['Powdered Mixed Berry Extract Supplement'] ['C172110']
# ['Antitumor B Key Active Component-alpha'] ['C156694']
# ['Glycocyamine'] ['C83736']
# ['Guanidine Hydrochloride'] ['C47551']
# ['Milotane'] ['C2091']
# ['Aluminum Carbonate'] ['C120559']
# ['Anti-IL-6 Monoclonal Antibody'] ['C163951']
# ['Angelica sinensis Root Extract'] ['C60817']
# ['Potassium Lactate'] ['C77489']
# ['Polyethylene Glycol'] ['C762']
# ['STAMP'] ['C29438']
# ['Acetohydroxamic Acid'] ['C47381']
# ['1Alpha-Hydroxyvitamin D5'] ['C63679']
# ['Betaine'] ['C81038']
# ['IDH1 inhibitor'] ['C168618']
# ['Carcinoembryonic Antigen Peptide 1'] ['C2414']
# ['Entsufon'] ['C80854']
# ['Dimethylaminoethyl Methacrylate - Butyl Methacrylate - Methyl Methacrylate Copolymer'] ['C82310']
# ['Ensaculin'] ['C74243']
# ['Botulinum Toxin Type A2'] ['C163592']
# ['THL-P'] ['C88275']
# ['Kefir'] ['C173982']
# ['mRNA Vaccine'] ['C172787']
# ['Ferrous Fumarate'] ['C61763']
# ['Sanguinarium'] ['C81358']
# ['Gluceptate Sodium'] ['C76600']
# ['Choline Bitartrate'] ['C76834']
# ['Doxorubicin Preparation'] ['C67502']
# ['Magnesium-rich Mineral Water'] ['C148542']
# ['Sodium Cromoglycate'] ['C29458']
# ['4-Chlorophenyl Acetate'] ['C63700']
# ['Adenosine Phosphate'] ['C83606']
# ['Berberine Chloride'] ['C87331']
# ['Mineral Oil'] ['C29264']
# ['Antiseborrheic Agent'] ['C2390']
# ['Magnesium Sulfate Heptahydrate'] ['C77475']
# ['Flavin Adenine Dinucleotide'] ['C80888']
# ['Fluorouracil-Uracil'] ['C11280']
# ['Ergotamine'] ['C61751']
# ['Thioguanine'] ['C876']
# ['TNP-40'] ['C2046']
# ['L-alpha-Aminobutyric Acid'] ['C61804']
# ['Idronoxil'] ['C73317']
# ['Tromethamine'] ['C47775']
# ['Tyloxapol'] ['C80949']
# ['Oxybutynin Chloride'] ['C29308']
# ['P32'] ['C29315']
# ['Dichlorodifluoromethane'] ['C76746']
# ['HER2-targeting Agent'] ['C163760']
# ['Phytate Sodium'] ['C87690']
# ['Interferon Beta-1A'] ['C1823']
# ['Cryptoporic Acid E'] ['C63642']
# ['Ceruletide'] ['C65309']
# ['Phenylmercuric Nitrate'] ['C84052']
# ['Non-Steroidal Estrogen'] ['C2182']
# ['Carbestrol'] ['C28879']
# ['Rubidium Rb-86'] ['C87415']
# ['Phenyl Acetate'] ['C1501']
# ['Eniluracil'] ['C1773']
# ['Tribehenin'] ['C78765']
# ['Attenuated Live Vaccine'] ['C97116']
# ['Anticholinergic Agent'] ['C66880']
# ['Calomel'] ['C76865']
# ['Recombinant Delta Chemokine'] ['C2256']
# ['Octoxynol 9'] ['C80935']
# ['Branched-chain Amino Acid Supplement'] ['C120121']
# ['Antineoplastic Antibody-Drug Conjugate'] ['C129823']
# ['Thymosin Fraction 5'] ['C29477']
# ['Anti-HER2 Antibody-drug Conjugate'] ['C155712']
# ['Gene-Vector Complex'] ['C2175']
# ['Whey Protein Isolate-based  Nutritional Supplement'] ['C158605']
# ['Attenuated Bacteria Vaccine'] ['C62761']
# ['Sevelamer'] ['C84172']
# ['Propylene Glycol'] ['C29388']
# ['CD30-targeting Agent'] ['C164005']
# ['Nicotinic Agonist'] ['C73579']
# ['Tannic Acid'] ['C66579']
# ['Amicloral'] ['C142920']
# ['Isopropyl Myristate'] ['C76717']
# ['Recombinant Granulocyte-Macrophage Colony-Stimulating Factor'] ['C1288']
# ['Recombinant Urokinase'] ['C38165']
# ['Dihydroxyacetone'] ['C76586']
# ['Cotarnine Chloride'] ['C79997']
# ['Diatrizoate Meglumine'] ['C47982']
# ['Docetaxel'] ['C1526']
# ['Anti-SLAMF7 Monoclonal Antibody'] ['C158974']
# ['Ricin Immunoconjugate'] ['C2359']
# ['Swiss Kiss'] ['C29473']
# ['Milk Protein-Based Energy Drink'] ['C77871']
# ['Immunomodulatory Imide Drug'] ['C157388']
# ['Iodine I 131 Tositumomab'] ['C37446']
# ['Methylcellulose'] ['C28933']
# ['Sargramostim'] ['C1492']
# ['Carbohydrate Supplement Drink'] ['C107165']
# ['Glutaurine'] ['C72802']
# ['Lumretuzumab'] ['C170139']
# ['Merphalen'] ['C29692']
# ['PDGFR-targeting Agent'] ['C164037']
# ['Polysorbate Monooctadecanoate'] ['C81925']
# ['Anti-CD7 Immunotoxin'] ['C2435']
# ['Analgesic Agent'] ['C241']
# ['Edetate Disodium'] ['C61741']
# ['APC Vaccine'] ['C28308']
# ['Tribasic Calcium Phosphate'] ['C84224']
# ['Alpha-Ketoglutaric Acid'] ['C83527']
# ['Anatabine'] ['C114277']
# ['Anti-PD-L1 Monoclonal Antibody'] ['C128057']
# ['Protoveratrine A'] ['C81361']
# ['Falecalcitriol'] ['C80884']
# ['Melizame'] ['C66081']
# ['Desmeninol'] ['C77373']
# ['Cupric Sulfate Anhydrous'] ['C83640']
# ['Anti-CD19 Immunotoxins'] ['C2330']
# ['Pendecamaine'] ['C66338']
# ['Reproductive Human Cells, Tissues, and Cellular and Tissue-Based Products from Sexually Intimate Partner'] ['C133316']
# ['Potassium Benzoate'] ['C84094']
# ['Prolgolimab'] ['C170356']
# ['ERB-38 Immunotoxin'] ['C2453']
# ['Pentosan'] ['C29350']
# ['B Vitamin'] ['C45812']
# ['Ipriflavone'] ['C63694']
# ['Epoetin Delta'] ['C166731']
# ['Monophosphothiamine'] ['C66188']
# ['Antineoplastic Antibody'] ['C129822']
# ['Eicosapentaenoic Acid Monoacylglyceride'] ['C158515']
# ['BCG'] ['C1328']
# ['D Vitamin'] ['C941']
# ['Shu Yu Wan Formula'] ['C120207']
# ['Lexacalcitol'] ['C80885']
# ['PRMT5 Inhibitor'] ['C163968']
# ['Modified-release Calcifediol Capsule'] ['C118789']
# ['Deferoxamine Hydrochloride'] ['C1972']
# ['Interferon Gamma-1b'] ['C100089']
# ['Manuka Honey'] ['C74058']
# ['Poloxamer 407'] ['C84071']
# ['EGFR-targeting Agent'] ['C163952']
# ['StudyMed 00C0080'] ['C29464']
# ['Coumaphos'] ['C76867']
# ['Cholecalciferol'] ['C48194']
# ['Lorcet'] ['C29164']
# ['Multitargeted Tyrosine Kinase Inhibitor BIBF 1120'] ['C79846']
# ['Nutritious Semisolid Food Gel'] ['C148136']
# ['Edetate Sodium'] ['C76598']
# ['OxyContin'] ['C721']
# ['Zinc Sulfide'] ['C66694']
# ['Sodium Succinate Hexahydrate'] ['C66554']
# ['Diethylene Glycol Monoethyl Ether'] ['C65380']
# ['Cation Channel Blocker'] ['C93038']
# ['Amorphous Calcium Carbonate'] ['C148184']
# ['Phenoxyethylparaben'] ['C92609']
# ['Anethole'] ['C76862']
# ['Eldecalcitol'] ['C87291']
# ['Visilizumab'] ['C2229']
# ['Cholecystokinin B Receptor Antagonist YF476'] ['C96427']
# ['Therapeutic Allogeneic Lymphocytes'] ['C28676']
# ['Monobenzone'] ['C992']
# ['VAC0P'] ['C29533']
# ['PCLUS 3:18MN/PCLUS 6.1:18MN'] ['C29318']
# ['Folate Sodium'] ['C76079']
# ['Serotonin Agonist'] ['C47794']
# ['Nonanoic Acid'] ['C82932']
# ['Linarotene'] ['C77397']
# ['Aluminum Sulfate'] ['C28200']
# ['Whey Protein Isolate'] ['C67285']
# ['Trisodium Citrate Dihydrate'] ['C66642']
# ['EZH2 Inhibitor'] ['C156804']
# ['Oxycodone/Rixicodone'] ['C29312']
# ['Povidone K90'] ['C82263']
# ['Xenon Xe-127'] ['C77512']
# ['narcotic'] ['C28171']
# ['Potassium Sulfate'] ['C80907']
# ['ZD0473'] ['C1793']
# ['Calcium Acetate'] ['C47429']
# ['Adenovirus Agent'] ['C2307']
# ['Cathepsin-cleavable NIR Substrate Probe 6QC-ICG'] ['C167239']
# ['Lactase'] ['C29147']
# ['Anhydrous Dibasic Calcium Phosphate'] ['C77523']
# ['Epipodophyllotoxin Compound'] ['C1331']
# ['ATR Inhibitor'] ['C155926']
# ['Tolevamer'] ['C152681']
# ['Yi Qi Fang'] ['C129988']
# ['Edetate Trisodium'] ['C76599']
# ['Lyophilized Black Raspberry Saliva Substitute'] ['C99164']
# ['Methylparaben Sodium'] ['C77479']
# ['Evicromil'] ['C65606']
# ['M A T101 HUMAN T-LYMPHOCYTE'] ['C29182']
# ['Methylmethionine Sulfonium Chloride'] ['C82926']
# ['Synbiotic Supplement'] ['C99230']
# ['Oblimersen'] ['C1870']
# ['Trastuzumab Deruxtecan'] ['C152716']
# ['Zoledronic Acid Anhydrous'] ['C80120']
# ['Menatetrenone'] ['C52194']
# ['Aluminum Chloride'] ['C83530']
# ['Methylparaben'] ['C76720']
# ['Sodium Tartrate'] ['C77502']
# ['Lactobacillus reuteri Probiotic Tablet'] ['C148148']
# ['Indatuximab Ravtansine'] ['C170064']
# ['Zinc Acetate'] ['C47787']
# ['Cuproxoline'] ['C83641']
# ['Dichlorotetrafluoroethane'] ['C76747']
# ['JAK Inhibitor'] ['C172200']
# ['Magnesium Sulfate'] ['C623']
# ['Botulinum Toxin Type A7'] ['C163597']
# ['Ellagic Acid/Annona muricata Supplement'] ['C118627']
# ['Balsam Peru'] ['C66361']
# ['Milatuzumab'] ['C82360']
# ['Ammonium Carbonate'] ['C82281']
# ['Sudismase'] ['C152446']
# ['Azacitidine'] ['C288']
# ['Gamma-Aminobutyric Acid'] ['C80523']
# ['Sodium Perborate Monohydrate'] ['C84165']
# ['Therapeutic Autologous Dendritic Cells'] ['C2594']
# ['Monoxerutin'] ['C77402']
# ['Prostate Health Cocktail Dietary Supplement'] ['C77860']
# ['Wild Type and Mutant MGMT Vector'] ['C29548']
# ['Edodekin alfa'] ['C1380']
# ['Chromic Chloride'] ['C61675']
# ['Zinc Aspartate'] ['C87349']
# ['6-Chloroflavone'] ['C63698']
# ['Beta-glucan/Lactobacillus casei/Bifidobacterium lactis-based Supplement'] ['C99227']
# ['Cyclopamine'] ['C63945']
# ['Hypotensive Agent'] ['C29722']
# ['Dimethyl Sulfoxide'] ['C437']
# ['Disease-Modifying Antirheumatic Drug'] ['C121332']
# ['Glucarpidase'] ['C346']
# ['Oligonucleotide Linker'] ['C29690']
# ['Anti-CD30 Antibody-drug Conjugate'] ['C158973']
# ['Dextran Sulfate Sodium'] ['C1284']
# ['Tiapirinol'] ['C91008']
# ['Iodide Ion I-131'] ['C87413']
# ['Tiazofurin'] ['C1254']
# ['Largetrifoliolious Bugbane Rhizome Supplement'] ['C103271']
# ['Sodium Propionate'] ['C84167']
# ['Fluorine F 18 Choline'] ['C91071']
# ['Polyethylene Glycol 4000'] ['C84081']
# ['Isopimpinellin'] ['C63673']
# ['Citrate'] ['C63374']
# ['Variconazole'] ['C29537']
# ['Flavodic Acid'] ['C65690']
# ['Sheng-Mai San'] ['C102756']
# ['Menadiol Sodium Sulfate'] ['C66085']
# ['Delmopinol'] ['C78112']
# ['Isobutylparaben'] ['C92610']
# ['Varicella Vaccine'] ['C96395']
# ['Follicle Stimulating Hormone Beta Polypeptide'] ['C77385']
# ['Calcium Lactate'] ['C76830']
# ['Vofatamab'] ['C121649']
# ['Sparfosic Acid'] ['C1398']
# ['Gallium Nitrate'] ['C1109']
# ['BTK Inhibitor'] ['C124801']
# ['Multicarotenoid Supplement MCS-8'] ['C121859']
# ['Isopropylparaben'] ['C92611']
# ['Recombinant Interferon Gamma'] ['C583']
# ['Thymidylate Synthase Inhibitor'] ['C2021']
# ['MOAB Colorectal Carcinoma'] ['C29221']
# ['Indigotindisulfonate Sodium'] ['C83799']
# ['1,25-Dihydroxy-16-ene-23-yne-Vitamin D3'] ['C63681']
# ['Brucine'] ['C87455']
# ['Lactobacillus Probiotic BSL_PS6'] ['C171095']
# ['Trichlormethine'] ['C75296']
# ['Zinc Lactate'] ['C84249']
# ['Gastrin Releasing Peptide (Therapeutic)'] ['C1111']
# ['Peginesatide Acetate'] ['C166719']
# ['Von Hippel-Lindau Peptide Vaccine'] ['C2492']
# ['Dexpanthenol'] ['C47481']
# ['Hydromadinone'] ['C83766']
# ['Allogeneic Melanoma Cell-Loaded Dendritic Cell Vaccine'] ['C49086']
# ['Potassium Chlorate'] ['C84096']
# ['Beta-D-Glucopyranose Monohydrate'] ['C61651']
# ['Glyceryl Ricinoleate'] ['C75645']
# ['Methylene Blue'] ['C644']
# ['Lycopene'] ['C2226']
# ['Povidone'] ['C77491']
# ['Asparagine Anhydrous'] ['C87330']
# ['Butyrophenone'] ['C323']
# ['Molybdenum Mo-99'] ['C80646']
# ['Asulacrine'] ['C79788']
# ['6-Phenylhexyl Isothiocyanate'] ['C63643']
# ['Lotrifen'] ['C66038']
# ['Sodium Sulfite'] ['C28205']
# ['Bispecific Antibody'] ['C1454']
# ["Nature's Remedy"] ['C29282']
# ['Azaribine'] ['C76914']
# ['Melanoma Vaccine'] ['C2517']
# ['M-BADOC'] ['C29185']
# ['Antineoplastic Hormonal/Endocrine Agent'] ['C129818']
# ['Povidone K26/28'] ['C82260']
# ['Xenon Xe-133'] ['C47784']
# ['Daunorubicin/Cytarabine Liposome'] ['C154676']
# ['Palmitoyl Thioesterase Inhibitor'] ['C2154']
# ['Se-Methyl-seleno-L-cysteine'] ['C68823']
# ['Probiotic Supplement WeiLeShu'] ['C172102']
# ['Non-Viral Vector-Gene Complex'] ['C2177']
# ['IDEC-In2B8'] ['C2511']
# ['HER-2-neu, CEA Peptides, GM-CSF, Montanide ISA-51 Vaccine'] ['C48392']
# ['Brassinin'] ['C63657']
# ['Domiphen Bromide'] ['C72644']
# ['Recombinant Thymosin'] ['C883']
# ['Potassium Aspartate'] ['C87343']
# ['3,6-Dinitroflavone'] ['C63773']
# ['Nitric Oxide Synthase Inhibitor'] ['C29574']
# ['Batabulin Sodium'] ['C73257']
# ['Orotic Acid Monohydrate'] ['C87341']
# ['Novel Erythropoiesis Stimulating Protein'] ['C2014']
# ['Non-Statin Antilipidemic Agent'] ['C80482']
# ['Ganoderma lucidum Spores Powder Capsule'] ['C118365']
# ['Piperine Extract (Standardized)'] ['C48417']
# ['Clostridium butyricum CBM 588 Probiotic Strain'] ['C154674']
# ['Sodium Nitrate Supplement'] ['C131823']
# ['Formic Acid'] ['C83719']
# ['Sodium Caseinate'] ['C84151']
# ['4-Bromoflavone'] ['C63748']
# ['Anti-CCR4 Monoclonal Antibody'] ['C163950']
# ['Iron Dextran Complex'] ['C44394']
# ['Gluten-free DHA/EPA/GLA/Antioxidant-rich Nutritional Liquid'] ['C128027']
# ['PVA Microporous Hydrospheres'] ['C71147']
# ['Pimecrolimus'] ['C47671']
# ['Ringer Solution'] ['C65146']
# ['Mustard Prodrug'] ['C2129']
# ['Cotarnine'] ['C79913']
# ['Conjugate Vaccine'] ['C1455']
# ['Vicodin'] ['C29541']
# ['Recombinant Interferon Alfa'] ['C225']
# ['FDG'] ['C29039']
# ['Alpha-D-Glucopyranose'] ['C77427']
# ['Recombinant Interleukin-3'] ['C588']
# ['Sumarotene'] ['C74431']
# ['Nicotinic Antagonist'] ['C66886']
# ['Saccharin'] ['C76515']
# ['Carnosine/Hibiscus-based Oral Mucoadhesive Tablet'] ['C165552']
# ['BTK Inhibitor BGB-3111'] ['C120215']
# ['Aluminum Chlorohydrate'] ['C142916']
# ['Chloroaluminum Phthalocyanine'] ['C1048']
# ['B43 Immunotoxin'] ['C2332']
# ['Hyaluronate Sodium'] ['C83761']
# ['Acesulfame'] ['C76511']
# ['Pyrogallol'] ['C80909']
# ['Lidadronic Acid'] ['C82323']
# ['Tumor Cell Derivative Vaccine'] ['C2341']
# ['Peripheral Blood Lymphocyte Vaccine'] ['C2841']
# ['Tolevamer Potassium Sodium'] ['C152682']
# ['Indole-3-Carbinol'] ['C1135']
# ['Abafilcon A'] ['C142895']
# ['Pegfilgrastim (Neulasta)'] ['C29348']
# ['Carboxymethylcellulose Sodium'] ['C83596']
# ['Bizelesin'] ['C1472']
# ['Polysorbate 80'] ['C80656']
# ['Recombinant Cytokine'] ['C1283']
# ['Promegestone'] ['C66478']
# ['N-Acetylglucosamine'] ['C83975']
# ['dl-Alpha-Tocopherol Acetate'] ['C74961']
# ['Xiaoai Jiedu Decoction'] ['C165272']
# ['Monosodium Glutamate Anhydrous'] ['C82289']
# ['Tributyrin'] ['C1260']
# ['Cupric Sulfate'] ['C65354']
# ['Monoclonal Antibody Bombesin-DTPA'] ['C42055']
# ['Stannous Tartrate'] ['C77506']
# ['Nicarbazin'] ['C76086']
# ['Light Mineral Oil'] ['C80302']
# ['Polyethylene Glycol 400'] ['C84080']
# ['Buthionine Sulfoximine'] ['C1029']
# ['Recombinant Erythropoietin'] ['C477']
# ['CD20-targeting Agent'] ['C164034']
# ['Gluconic Acid'] ['C61777']
# ['Pyridoxal Phosphate'] ['C81627']
# ['Calcium Citrate'] ['C1355']
# ['Direct Thrombin Inhibitor'] ['C173066']
# ['Intrinsic Factor'] ['C99769']
# ['Efepoetin Alfa'] ['C169930']
# ['Palifermin'] ['C43599']
# ['Aluminum Hydroxide/Magnesium Hydroxide'] ['C29273']
# ['Duodenum'] ['C23196']
# ['4-Methoxy-3-Nitroflavone'] ['C63943']
# ['Para-Cresol'] ['C61880']
# ['Epoetin Zeta'] ['C102571']
# ['Flt-3-targeting Agent'] ['C163790']
# ['Starch, Corn'] ['C80778']
# ['Botulinum Toxin Type A5'] ['C163595']
# ['Progestin'] ['C776']
# ['Lidobenalox Solution'] ['C29156']
# ['Lactobacillus-based Probiotic Capsule'] ['C120549']
# ['Starch, Tapioca'] ['C80781']
# ['Docetaxel Formulation CKD-810'] ['C165259']
# ['Dihydro-5-Azacytidine'] ['C980']
# ['Chromic Sulfate Decahydrate'] ['C87466']
# ['Dacomitinib'] ['C95799']
# ["Riboflavin 5'-Phosphate Sodium"] ['C48016']
# ['RET Inhibitor'] ['C159438']
# ['Reproductive Human Cells, Tissues, and Cellular and Tissue-Based Products from Known Donor to Directed Recipient'] ['C133315']
# ['Sheddase Inhibitor INCB007839'] ['C82692']
# ['Recombinant Interleukin-1-alpha'] ['C1754']
# ['Sulfuric Acid'] ['C28191']
# ['Therapeutic Corticotropin-Releasing Factor'] ['C394']
# ['PARP1 Inhibitor PF-01367338'] ['C88306']
# ['Hydroxypropylcellulose'] ['C29139']
# ['Sodium Acetate Anhydrous'] ['C48017']
# ['High Fructose Corn Syrup'] ['C87668']
# ['Human Lysozyme-containing Goat Milk'] ['C174399']
# ['Sodium Pidolate'] ['C84058']
# ['Calcium Pantothenate'] ['C74545']
# ['Coffee Dietary Supplement'] ['C113662']
# ['Concentrated Fortified Collagen Protein Hydrolysate Liquid Supplement'] ['C124658']
# ['Letibotulinumtoxina'] ['C170111']
# ['Glucosamine Sulfate'] ['C29075']
# ['Iodine I-123'] ['C64794']
# ['Eflornithine'] ['C226']
# ['Hycaptmn'] ['C29096']
# ['CpG-28 Oligodeoxynucleotide'] ['C60806']
# ['Acetiamine'] ['C81634']
# ['Dextropropoxyphene Hydrochloride'] ['C63538']
# ['Afimoxifene'] ['C72683']
# ['Citicoline'] ['C96743']
# ['Viral Vector-Gene Complex'] ['C2176']
# ['Sorbitan Tristearate'] ['C75658']
# ['Cocoa Extract'] ['C121851']
# ['Dopamine Antagonist'] ['C66883']
# ['Pomegranate Liquid Extract'] ['C78866']
# ['Glycine Hydrochloride'] ['C79999']
# ['MOv-gamma'] ['C29233']
# ['Sodium Phenylbutyrate'] ['C1440']
# ['Ammonium Acetate'] ['C77452']
# ['RV-B7 (RECOMB VACCINIA/B7)'] ['C29408']
# ['Vitamin E Compound'] ['C942']
# ['y2B8'] ['C29567']
# ['Pharmaceutical Product-related Substance'] ['C42666']
# ['Brimodine'] ['C28873']
# ['SS1(dsFv) PE38'] ['C29437']
# ['Recombinant Parathyroid Hormone'] ['C62555']
# ['Ammonium Bicarbonate'] ['C82279']
# ['Prolinethiuramdisulfide'] ['C64180']
# ['PTF'] ['C29342']
# ['Anti-Inflammatory Agent'] ['C256']
# ['Phytate Persodium'] ['C167212']
# ['Limonene, (+/-)-'] ['C61709']
# ['Prolonium Iodide'] ['C74336']
# ['Lactobacillus rhamnosus/L. acidophilus/L. plantarum/ Enterococcus faecium Aqueous Probiotic Supplement'] ['C157490']
# ['Doxercalciferol'] ['C2645']
# ['Arsanilic Acid'] ['C75246']
# ['Semaxanib'] ['C1831']
# ['MDM2 Inhibitor KRT-232'] ['C156415']
# ['Antineoplastic Immune Cell'] ['C129826']
# ['Triacetin'] ['C82268']
# ['Fluoxamine'] ['C29059']
# ['Hou Gu Mi Xi'] ['C143159']
# ['Beta-D-Glucopyranose'] ['C61650']
# ['MVA-HPV16E6/E7-IL2 Vaccine TG4001'] ['C153381']
# ['Dioxamate'] ['C65415']
# ['Unithiol'] ['C87691']
# ['Green Tea Extract-based Antioxidant Supplement'] ['C97514']
# ['Squalene'] ['C77219']
# ['Sodium Fluoride'] ['C832']
# ['Therapeutic Estrogen'] ['C483']
# ['Skin Test Vaccine'] ['C29693']
# ['Anti-DR5 Monoclonal Antibody'] ['C171189']
# ['Beta-D-Fructopyranose'] ['C77428']
# ['Akt Inhibitor'] ['C155764']
# ['Zinc Acetate, Basic'] ['C152956']
# ['Hetaflur'] ['C65846']
# ['Benzylparaben'] ['C95327']
# ['Atocalcitol'] ['C79581']
# ['Sorbitan Monooleate'] ['C75654']
# ['Bifidobacterium longum/Lactobacillus acidophilus/Enterococcus faecalis Probiotic Supplement'] ['C162855']
# ['Gamma-D-Glutamyl-L-Tryptophan'] ['C80054']
# ['Phenothiazine'] ['C740']
# ['Recombinant Fowlpox-B7.1'] ['C2838']
# ['Cysteine Hydrochloride'] ['C65361']
# ['Propylparaben'] ['C76730']
# ['Anti-TIM3 Checkpoint Inhibitor MBG453'] ['C125187']
# ['Allogeneic Tumor Cell Vaccine'] ['C1983']
# ['Calcifediol'] ['C65278']
# ['Strawberry-Blackberry-Black Raspberry-Blueberry Mixture'] ['C77873']
# ['Arginine Glutamate'] ['C76828']
# ['Doconexent'] ['C75994']
# ['5-HT3 Receptor Antagonist'] ['C94726']
# ['Sodium Alginate'] ['C84148']
# ['Ranelic Acid'] ['C76602']
# ['L-Carnitine L-Tartrate'] ['C80057']
# ['Cocarboxylase'] ['C81632']
# ['Garlic'] ['C38706']
# ['Essiac'] ['C26649']
# ['Mistletoe Extract'] ['C2703']
# ['D-Serine'] ['C61739']
# ['Nutritious Semisolid Food Gel with Phenethyl Isothiocyanate'] ['C148137']
# ['Lodenosine'] ['C1499']
# ['Peri-Colace'] ['C29352']
# ['ERK Inhibitor'] ['C174048']
# ['Mai Dong'] ['C129584']
# ['Butylparaben Sodium'] ['C83570']
# ['Shu Di Huang'] ['C129583']
# ['Trichomonacide Agent'] ['C279']
# ['Anti-PD1 Monoclonal Antibody'] ['C128037']
# ['Dimercaprol'] ['C47494']
# ['Aluminum Subacetate'] ['C77451']
# ['BCR-ABL Peptide Vaccine'] ['C2205']
# ['Zinc Picolinate'] ['C87350']
# ['TNF Gene Transduced TIL'] ['C29479']
# ['Rhubarb/Licorice Herbal Supplement'] ['C99635']
# ['CD38-targeting Agent'] ['C164008']
# ['Medronic Acid'] ['C66071']
# ['Omacetaxine Mepesuccinate'] ['C1127']
# ['Rubidium Rb-82'] ['C87414']
# ['Beta-hydroxy-beta-methylbutyrate Supplement'] ['C102547']
# ['Pyrazoloacridine'] ['C29394']
# ['Bispecific Antibody 2B1'] ['C2399']
# ['Flavamine'] ['C65689']
# ['Methacrylic Acid'] ['C61838']
# ['Limonene'] ['C68543']
# ['Linker-Oligonucleotide'] ['C1942']
# ['StudyMed 98C0118'] ['C29465']
# ['EGFR Mutant-selective Inhibitor AC0010MA'] ['C122392']
# ['Tisocalcitate'] ['C66606']
# ['BLED'] ['C28854']
# ['Canventol'] ['C63650']
# ['HSP90 Inhibitor'] ['C156880']
# ['Phase I Enzymes Inhibitor'] ['C54629']
# ['Iron Sucrose Injection'] ['C60883']
# ['Bornyl Acetate'] ['C142964']
# ['Tacedinaline'] ['C76680']
# ['Arginine/Nucleotides/Omega-3 Fatty Acids/Olive Oil Polyphenols/Antioxidants/L-carnitine Oral Supplement'] ['C171099']
# ['Beclotiamine'] ['C74430']
# ['3-Nitroflavone'] ['C63956']
# ['Stomach'] ['C23326']
# ['Zinc Sulfate'] ['C1280']
# ['Therapeutic Testosterone'] ['C862']
# ['Vitamin K Antagonist'] ['C173064']
# ['EGFR Inhibitor PF-00299804'] ['C88291']
# ['Hydrastine Hydrochloride'] ['C76032']
# ['Paclitaxel'] ['C1411']
# ['Recombinant Tyrosinase-Related Protein-2'] ['C38769']
# ['Warfarin Potassium'] ['C66658']
# ['Raltitrexed'] ['C1804']
# ['Polyvinyl Alcohol'] ['C29370']
# ['Daunorubicin-DNA Complex'] ['C1061']
# ['Sorbitan Trioleate'] ['C75657']
# ['Nerve Growth Factor Mimetic'] ['C154292']
# ['Glyceryl Laurate'] ['C75644']
# ['Arsenic Trioxide'] ['C1005']
# ['Bushen Culuan Decoction'] ['C160712']
# ['Cropropamide'] ['C81396']
# ['Anti-CD22 Antibody-drug Conjugate'] ['C155713']
# ['Monosodium Glutamate'] ['C82288']
# ['Cremophor'] ['C28896']
# ['Levomefolic Acid'] ['C81119']
# ['Talc'] ['C854']
# ['Divalproex Sodium'] ['C65447']
# ['Saccharomyces boulardii Probiotic Supplement'] ['C102567']
# ['Anoxomer'] ['C142926']
# ['Sodium Iodide'] ['C80943']
# ['Tumor Necrosis Factor (Knoll)'] ['C2244']
# ['Rou Cong Rong'] ['C129586']
# ['Stannous Chloride'] ['C74343']
# ['Phase II Enzymes Inducer'] ['C54630']
# ['Dopamine Agonist'] ['C66884']
# ['Menadoxime'] ['C91007']
# ['1,3-Dithiole-2-Thione'] ['C63697']
# ['Zinc Sulfate Monohydrate'] ['C75660']
# ['Naratuximab Emtansine'] ['C170199']
# ['Butedronate Tetrasodium'] ['C87458']
# ['Ammonium Phosphate, Dibasic'] ['C76739']
# ['MCT/LCT Lipid Emulsion'] ['C79837']
# ['Cifostodine'] ['C76915']
# ['Maleic Acid'] ['C61821']
# ['Nitroestron Meth ETH'] ['C29278']
# ['Guanidine'] ['C77851']
# ['Fumaric Acid'] ['C63655']
# ['Tropantiol'] ['C76601']
# ['Vaccinia-GM-CSF Vaccine'] ['C2674']
# ['Pyrazole Compound'] ['C29396']
# ['Recombinant Flt3 Ligand'] ['C1714']
# ['Chondrus ocellatus Extract'] ['C73325']
# ['Transcrocetinate'] ['C152713']
# ['Monosialotetrahexosylganglioside'] ['C107389']
# ['Interferon-alpha Inducible Protein 10'] ['C20472']
# ['Hormone Therapy Agent'] ['C147908']
# ['Doxycycline Chloride'] ['C29009']
# ['Surgical Adjuvant'] ['C2142']
# ['TRK Inhibitor'] ['C155765']
# ['Calcium Lactophosphate'] ['C76832']
# ['Prothioconazole'] ['C97996']
# ['Casein/Whey Protein/Soy Protein/Pea Protein/Fat Mix/EPA/DHA-based Nutritional Supplement'] ['C121643']
# ['Fosfocreatinine'] ['C65759']
# ['Esculin'] ['C83696']
# ['Anti-TIM-3 Monoclonal Antibody'] ['C141146']
# ['Polyethylene Glycol 8000'] ['C84088']
# ['Ethylene Glycol Monoethyl Ether'] ['C77465']
# ['Peanut Oil'] ['C66332']
# ['Alpha-lipoic Acid-Palladium/Vitamin/Mineral Supplement'] ['C106371']
# ['LMB-2 Immunotoxin'] ['C2513']
# ['cKIT-targeting Agent'] ['C163999']
# ['Alitame'] ['C74194']
# ['Nifabutin'] ['C29289']
# ['Multivitamins/Minerals'] ['C29270']
# ['Anti-Idiotype Vaccine'] ['C2590']
# ['Panthenol'] ['C82290']
# ['Oxitriptan'] ['C52181']
# ['Pegol-sihematide Injection'] ['C125064']
# ['Poloxamer 188'] ['C80936']
# ['Indolebutyric Acid'] ['C63656']
# ['Deguelin'] ['C63666']
# ['Aerosol Sargramostim'] ['C77915']
# ['Chlorine Dioxide'] ['C172619']
# ['Eledoisin'] ['C80866']
# ['Vaccinia Vaccine'] ['C2313']
# ['Magic Mouthwash'] ['C29238']
# ['Ceruletide Diethylamine'] ['C65310']
# ['Delta-Tocotrienol'] ['C116743']
# ['Calcium Ascorbate'] ['C77085']
# ['Recombinant Alpha Chemokine'] ['C1592']
# ['Denatured Absolute Ethanol'] ['C28805']
# ['Alloxan'] ['C83525']
# ['Influenza Vaccine'] ['C29120']
# ['Antineoplastic Protein Inhibitor'] ['C129824']
# ['Equilin'] ['C29020']
# ['Peg 400 Diluent'] ['C2788']
# ['Sofalcone'] ['C81118']
# ['Iron Sucrose'] ['C65963']
# ['Choline Chloride'] ['C76835']
# ['Recombinant Vascular Endothelial Growth Factor'] ['C1272']
# ['RTGF-Beta'] ['C29407']
# ['Cilengitide'] ['C1834']
# ['Pantothenic Acid'] ['C47783']
# ['Sodium Selenite'] ['C87346']
# ['Povidone K25'] ['C82259']
# ['Direct Factor Xa Inhibitor'] ['C173067']
# ['Alpha-Aminobutyric Acid'] ['C81116']
# ['Asian Ginseng'] ['C69298']
# ['Fish Oil/Glycerol/Egg Lecithin-based Emulsion'] ['C104273']
# ['DL-Alanine'] ['C61731']
# ['Biochanin A'] ['C28201']
# ['Yi Qi Yang Yin Fang'] ['C129996']
# ['Buffer'] ['C70815']
# ['PAX3/FKHR'] ['C2800']
# ['Propionic Acid'] ['C61911']
# ['Recombinant Chemokine'] ['C1593']
# ['Sodium Ferric Gluconate Complex in Sucrose'] ['C78185']
# ['Pain-relief Medication'] ['C94765']
# ['Kinase Inhibitor'] ['C2147']
# ['Ferrous Sulfate Anhydrous'] ['C77374']
# ['Electrolyte-free Parenteral Nutrition Emulsion'] ['C97255']
# ['Magnesium Orotate'] ['C87337']
# ['VEGFR2-targeted Contrast Agent BR55'] ['C95204']
# ['Antihemophilic Factor Human'] ['C81122']
# ['Benzoic Acid'] ['C61646']
# ['Leucocianidol'] ['C81117']
# ['Bovine Cartilage'] ['C2418']
# ['Conessine'] ['C79899']
# ['3-Nitro-2-Fluoroflavone'] ['C63776']
# ['Liboxin'] ['C29154']
# ['Acetone'] ['C29807']
# ['Non-Tumor Cell Derivative Vaccine'] ['C62712']
# ['Sorghum bicolor Supplement'] ['C111681']
# ['p-Benzoquinone'] ['C95317']
# ['Ferrous Sulfate, Dried'] ['C65678']
# ['Cinobufotalin'] ['C151929']
# ['Reproductive Human Cells, Tissues, and Cellular and Tissue-Based Products from Anonymous Donor'] ['C133314']
# ['Guarana Supplement'] ['C101130']
# ['Polyvalent Melanoma Vaccine'] ['C1633']
# ['Thienopyridine Antiplatelet Agent'] ['C80483']
# ['Manganese/L-alanine/Vitamin D3-containing Contrast Agent Formulation'] ['C168527']
# ['Deltamethrin'] ['C83658']
# ['BTK-targeting Agent'] ['C163774']
# ['Copper Gluconate'] ['C80050']
# ['Recombinant Interleukin-7'] ['C592']
# ['Edetate Calcium Disodium'] ['C334']
# ['3-AP/Fludarabine'] ['C38719']
# ['N-oleyl-phosphatidylethanolamine/Epigallocatechin Gallate Supplement'] ['C168614']
# ['Antihemophilic Factor, Human Recombinant'] ['C81123']
# ['Ferrous Iodide'] ['C87333']
# ['Orphan Drug'] ['C48201']
# ['Efaproxiral'] ['C37453']
# ['Ancestim'] ['C1646']
# ['Pantethine'] ['C87342']
# ['Aluminum Stearate'] ['C61631']
# ['Erythrocytes'] ['C23455']
# ['Human Cells, Tissues, and Cellular and Tissue-Based Products from Musculoskeletal Tissue'] ['C133364']
# ['Dibromannitol'] ['C28983']
# ['Gamma Interferon-SCH'] ['C29066']
# ['Lerociclib'] ['C170109']
# ['Niu Xi'] ['C129587']
# ['Pediatric Liquid Dosage Form'] ['C69042']
# ['Autologous-Cell Leukemia Vaccine'] ['C2023']
# ['Pre-1938 Product'] ['C99176']
# ['Iodine I-123'] ['C92223']
# ['Asparagine'] ['C29607']
# ['Lactobacillus rhamnosus/L. jensenii/L. crispatus/L. gasseri Oral Supplement'] ['C113645']
# ['pan FGFR Inhibitor PRN1371'] ['C125188']
# ['Recombinant Viral Vaccine'] ['C1572']
# ['Bryostatin 1'] ['C1026']
# ['2-Hydroxyethyl Methacrylate'] ['C47791']
# ['Recombinant CD40-Ligand'] ['C1437']
# ['Alfadex'] ['C76093']
# ['Sodium Taurodeoxycholate'] ['C80659']
# ['2-Methoxyestradiol'] ['C965']
# ['Cingestol'] ['C83626']
# ['EWS/FLI 1 Type 2'] ['C2750']
# ['Epigallocatechin Gallate'] ['C1088']
# ['Botulinum Toxin Type A8'] ['C163598']
# ['Botulinum Toxin Type A'] ['C82623']
# ['Medronate Disodium'] ['C76571']
# ['Aceneuramic Acid'] ['C80777']
# ['Emollient'] ['C467']
# ['Lactic Acid'] ['C76926']
# ['Histidine Monohydrochloride Monohydrate'] ['C87334']
# ['Peptide-dye Conjugate ALM-488'] ['C173380']
# ['Nonacog Alfa'] ['C82270']
# ['Pyridoxamine Phosphate'] ['C81633']
# ['Mivopenim'] ['C29266']
# ['Glucosamine'] ['C83731']
# ['Manganese Acetate'] ['C87338']
# ['Botulinum Toxin Type A4'] ['C163594']
# ['Docetaxel/flavopiradol'] ['C28998']
# ['Cidan Herbal Capsule'] ['C118451']
# ['3-Nitro-4-Chloroflavone'] ['C63772']
# ['Succinic Acid'] ['C61954']
# ['Alpha-lipoic Acid/Boswellia Serrata Extract/Methylsulfonylmethane/Bromelain Dietary Supplement'] ['C174411']
# ['Cycotiamine'] ['C81629']
# ['Perillyl Alcohol'] ['C1461']
# ['Nedisertib'] ['C157064']
# ['NY-ESO-1 Peptide Vaccine'] ['C2657']
# ['Acetyl-L-Carnitine Hydrochloride'] ['C61624']
# ['Peptidoglycan Complex of Spirulina K-001'] ['C174514']
# ['TBC-CEA-Contaminated W/ BVDV'] ['C29476']
# ['Aluminum Chlorohydrex Propylene Glycol'] ['C142917']
# ['Selenium'] ['C825']
# ['Recombinant Interleukin-1'] ['C586']
# ['Pyrazoloacridine'] ['C1564']
# ['Samrotamab Vedotin'] ['C170373']
# ['MKC-1'] ['C61496']
# ['Coagulation Factor VIIa Recombinant Human'] ['C81125']
# ['Polyvalent Vaccine'] ['C2848']
# ['Arginine/Omega-3 Fatty Acids/Nucleotides Oral Supplement'] ['C62534']
# ['Cresol'] ['C80922']
# ['Aspirin'] ['C287']
# ['3,6,4-Trinitroflavone'] ['C63774']
# ['Recombinant Thyrotropin Alpha'] ['C66871']
# ['Sodium Gluconate'] ['C47723']
# ['Fish Oil'] ['C497']
# ['Sodium Tripolyphosphate'] ['C77486']
# ['Chickweed Tincture'] ['C87560']
# ['Fibrin Sealant'] ['C2664']
# ['Acetylcarnitine'] ['C87329']
# ['N-Acetyltyrosine'] ['C61853']
# ['Thiram'] ['C66600']
# ['Hydroxamic Acids'] ['C556']
# ['Cinnamomum cassia Capsules'] ['C158094']
# ['Peptide Vaccine'] ['C1752']
# ['Iron Dextran'] ['C76837']
# ['Chlorpheniramine Polistirex'] ['C77433']
# ['Cholecalciferol/Whey Protein Isolate/EPA/DHA-based Nutritional Supplement'] ['C123916']
# ['Polysorbate 20'] ['C80937']
# ['HDAC Inhibitor PCI-24781'] ['C78841']
# ['Anti-GITR Monoclonal Antibody'] ['C128058']
# ['Sorbitan'] ['C75651']
# ['Saline'] ['C821']
# ["3'-C-ethynylcytidine"] ['C80037']
# ['Viscotoxin'] ['C28206']
# ['DL-Proline'] ['C61732']
# ['Olive Oil/Soya Oil/Egg Lecithin-based Emulsion'] ['C111896']
# ['Autologous Tumor Cells'] ['C2458']
# ['Viral Vaccine'] ['C96404']
# ['Sulbenox'] ['C74395']
# ['Iobenguane I-131'] ['C61790']
# ['Apoptotic Pathway-targeting Antineoplastic Agent'] ['C129839']
# ['Glycocholic Acid'] ['C77849']
# ['Chromium Cr-51'] ['C80652']
# ['Anti-CD137 Monoclonal Antibody'] ['C155745']
# ['Pegzerepoetin Alfa'] ['C87201']
# ['Toxicodendron pubescens Leaf'] ['C66450']
# ['Recombinant Interleukin-2'] ['C587']
# ['Neotame'] ['C81625']
# ['Recombinant Vaccinia-MUC1-B7.1'] ['C29562']
# ['Autologous Tumor Cell Vaccine'] ['C1980']
# ['Recombinant Fowlpox-GM-CSF'] ['C29975']
# ['Human Papilloma Virus Vaccine'] ['C1951']
# ['Alpha-D-Glucopyranose Monohydrate'] ['C61629']
# ['Casanthranol'] ['C28942']
# ['Ditiocarb Sodium'] ['C80963']
# ['Iodine I-125'] ['C1841']
# ['Limonene, (+)-'] ['C61714']
# ['Calcium Sulfate'] ['C65280']
# ['Adargileukin Alfa'] ['C171892']
# ['Gynostemma pentaphyllum Supplement'] ['C117275']
# ['Ferric Pyrophosphate'] ['C82284']
# ['Autologous-Cell Melanoma Vaccine'] ['C1981']
# ['TPH Inhibitor LX1606'] ['C88331']
# ['Deferoxamine'] ['C416']
# ['PRMT1 Inhibitor'] ['C158131']
# ['Tetraxetan'] ['C66592']
# ['Fat Emulsion'] ['C2575']
# ['Phenanthrene'] ['C84047']
# ['O6-Benzylguanine'] ['C1306']
# ['Butylparaben'] ['C76701']
# ['Babaodan Capsule'] ['C155974']
# ['1,4-Sorbitan'] ['C83509']
# ['Norleucine'] ['C87587']
# ['Citrulline'] ['C53406']
# ['Tris-acryl Gelatin Microspheres'] ['C126803']
# ['Anti-CD52 Monoclonal Antibody'] ['C72960']
# ['Phenylacetic Acid'] ['C77487']
# ['Aldose Reductase Inhibitor'] ['C72880']
# ['Isaxonine'] ['C65969']
# ['Diazolidinyl Urea'] ['C80924']
# ['Bacterial Vaccine'] ['C96390']
# ['Acetal'] ['C83515']
# ['Trehalose Dihydrate'] ['C87706']
# ['Protopine/Nuciferine Supplement'] ['C173963']
# ['Altrenogest'] ['C83529']
# ['L-Arginine/Korean Ginseng/Ginkgo biloba/Damiana-Based Supplement'] ['C67093']
# ['Strontium Chloride'] ['C84181']
# ['Medication'] ['C459']
# ['Glucosamine Hydrochloride'] ['C83732']
# ['Muscadine Grape Skin Extract'] ['C96231']
# ['Sucralose'] ['C79882']
# ['Therapeutic Corticosteroid'] ['C211']
# ['Calcifediol Anhydrous'] ['C77155']
# ['Adenovirus Vector'] ['C1890']
# ['Deferiprone'] ['C73030']
# ['Menadiol'] ['C73595']
# ['Marizomib'] ['C90932']
# ['Recombinant Heparin-Binding Neurotrophic Factor'] ['C2261']
# ['CODP-WAC'] ['C28891']
# ['Gemcitabine/Trastuzumab'] ['C29509']
# ['Blinded Medication'] ['C142408']
# ['Therapeutic Autologous Lymphocytes'] ['C28681']
# ['d-Alpha-Tocopherol Succinate'] ['C74963']
# ['Potassium Bitartrate'] ['C80939']
# ['Starch, Potato'] ['C80779']
# ['Myeloma Ig Id-KLH Conjugate Vaccine'] ['C2782']
# ['Thiophanate'] ['C76880']
# ['Ropeginterferon Alfa-2B'] ['C152250']
# ['Tiragolumab'] ['C152656']
# ['Recombinant Brain-Derived Growth Factors'] ['C1352']
# ['Recombinant Human Stem Cell Factor'] ['C1410']
# ['Clodronate Disodium Anhydrous'] ['C87474']
# ['Recombinant Human Endostatin'] ['C45515']
# ['Fursultiamine'] ['C121852']
# ['Opioid Receptor Agonist'] ['C67413']
# ['Medronate Tetrasodium'] ['C97314']
# ['dHER2 Vaccine+AS15 Adjuvant'] ['C84861']
# ['Recombinant Epidermal Growth Factor'] ['C1504']
# ['Valspodar'] ['C1405']
# ['Heptanoic Acid'] ['C61782']
# ['Tristearin'] ['C77514']
# ['Calcium Supplement'] ['C137864']
# ['Voxergolide'] ['C66657']
# ['Bortezomib'] ['C1851']
# ['Alitame Anhydrous'] ['C77135']
# ['Phenoxymethylpenicillin'] ['C29360']
# ['Saw Palmetto Berry Extract'] ['C1838']
# ['Prosultiamine'] ['C82256']
# ['Black Raspberry Nectar'] ['C122398']
# ['Dexrazoxane Hydrochloride'] ['C66945']
# ['Sodium Chloride 0.9%'] ['C2836']
# ['Dexrazoxane'] ['C1333']
# ['Recombinant Neuropoietic Cytokines'] ['C2260']
# ['Tocotrienol-rich Fraction'] ['C101518']
# ['Alvespimycin'] ['C79937']
# ['Dendritic Cell-G9-209-2M Peptide Vaccine'] ['C2427']
# ['Clofibric Acid'] ['C81531']
# ['Ecalcidene'] ['C74432']
# ['3-Tyrosine'] ['C61817']
# ['UVB'] ['C29529']
# ['Black Currant Juice'] ['C158098']
# ['Molgramostim'] ['C77591']
# ['Chlorophenothane'] ['C76866']
# ['Iodinated I-131 Serum Albumin'] ['C87396']
# ['OXY 104'] ['C29297']
# ['Commercial or Non-CTEP IND agent'] ['C28329']
# ['Spirulina-based Dietary Supplement'] ['C158092']
# ['Pharmaceutical Excipient'] ['C42637']
# ['DAB'] ['C28954']
# ['Recombinant Parathyroid Hormone-Related Protein'] ['C1185']
# ['Anti-OX40 Monoclonal Antibody'] ['C96040']
# ['Decitabine'] ['C981']
# ['Dextriferron'] ['C99877']
# ['Succinylated Dimer Form of'] ['C29466']
# ['Skatole'] ['C87586']
# ['Regramostim'] ['C170366']
# ['Sorbitan Monostearate'] ['C75656']
# ['Xantofyl Palmitate'] ['C66661']
# ['Dietary Carbohydrate'] ['C68470']
# ['Recombinant Vaccinia-B7.1'] ['C2840']
# ['Soy Protein Isolate'] ['C1803']
# ['Recombinant Platelet-Derived Growth Factor'] ['C755']
# ['Tri-N-butyl Phosphate'] ['C1259']
# ['Vitamins/Minerals/Proteins-based Synthetic Meal Replacement'] ['C173697']
# ['Alanylglutamine'] ['C127908']
# ['Cottonseed Meal'] ['C75634']
# ['Hydroquinone'] ['C29823']
# ['GRm13Z40-2'] ['C91067']
# ['Brucine Sulfate Heptahydrate'] ['C87456']
# ['Recombinant Vaccinia-PSA(L155)-TRICOM Vaccine'] ['C29565']
# ['Adenosine Triphosphate Disodium'] ['C83607']
# ['Recombinant Fibroblast Growth Factor'] ['C496']
# ['Recombinant Vaccinia-Tyrosinase'] ['C29947']
# ['MDX-447'] ['C2008']
# ['Sodium Equilin Sulfate'] ['C61941']
# ['Pediatric Nutritional Supplement Drink'] ['C74453']
# ['Magnesium Acetate Tetrahydrate'] ['C48001']
# ['Pentosalen'] ['C63672']
# ['SGN-15'] ['C2004']
# ['MCT/LCT/Fish Oil Omega-3 Fatty Acid Lipid Emulsion'] ['C79839']
# ['Sorbitan Monopalmitate'] ['C75655']
# ['DNA Vaccine'] ['C39619']
# ['Inulin'] ['C61506']
# ['Recombinant Neurotrophic Factor'] ['C2259']
# ['Saccharin Sodium Dihydrate'] ['C76516']
# ['Pheneridine'] ['C66370']
# ['Fowlpox Vaccine'] ['C2839']
# ['Echinacea pallida'] ['C65507']
# ['Aminobenzoate Sodium'] ['C77315']
# ['Maleic Acid'] ['C25951']
# ['Antineoplastic Immunomodulating Agent'] ['C129820']
# ['1,2-Dithiole-3-Thione'] ['C63644']
# ['Leucine-Enhanced Essential Amino Acid Dietary Supplement'] ['C82357']
# ['Benfotiamine'] ['C169805']
# ['Low-dose Aldesleukin ILT-101'] ['C172825']
# ['Recombinant Insulin-Like Growth Factor'] ['C835']
# ['Nadide'] ['C87339']
# ['Mifamurtide'] ['C1394']
# ['Tislelizumab'] ['C152661']
# ['Polypodium leucotomos Extract'] ['C129595']
# ['Polyethylene Glycol 1000'] ['C84072']
# ['Cilmostim'] ['C169847']
# ['Recombinant Fowlpox-TRICOM Vaccine'] ['C2667']
# ['Malic Acid'] ['C80654']
# ['Oral Medication'] ['C102246']
# ['Chk1 Inhibitor'] ['C155927']
# ['Zinc Citrate'] ['C84247']
# ['Iodine I 131 TM-601'] ['C78857']
# ['Pirenoxine'] ['C66416']
# ['Lithium Bromide'] ['C83888']
# ['Veltuzumab'] ['C90884']
# ['Calcium Lactobionate'] ['C76831']
# ['VHL Peptides'] ['C2823']
# ['Botulinum Toxin Type A6'] ['C163596']
# ['Recombinant Transforming Growth Factor-Beta'] ['C898']
# ['2-Mercaptobenzothiazole'] ['C83512']
# ['Morphine Sulfate'] ['C669']
# ['Stearyl Alcohol'] ['C76735']
# ['Fruit and Vegetable Extract'] ['C38707']
# ['Perifosine'] ['C1727']
# ['Urea/Lactic Acid-based Topical Cream'] ['C116892']
# ['Recombinant Transforming Growth Factor'] ['C899']
# ['ALVAC'] ['C2312']
# ['Conjugate'] ['C61533']
# ['Sevelamer Hydrochloride'] ['C66538']
# ['Hydroxymethanesulfinic Acid'] ['C77471']
# ['Clostridium butyricum-containing Probiotic'] ['C122837']
# ['Recombinant Vaccinia-GM-CSF'] ['C29976']
# ['Glutamine'] ['C522']
# ['EWS/FLI 1 Type 1'] ['C2749']
# ['Aloe Vera Oil'] ['C72198']
# ['Acetylcholinesterase Inhibitor'] ['C47792']
# ['Pyridoxine Hydrochloride'] ['C48030']
# ['Calcium Pantothenate'] ['C68510']
# ['Mecobalamin'] ['C173805']
# ['2-Deoxy-D-glucose'] ['C116618']
# ['Metalkonium Chloride'] ['C83944']
# ['Defined Green Tea Catechin Extract'] ['C38689']
# ['Chitin Oligosaccharides Supplement T-ChOS'] ['C129312']
# ['Aldesleukin'] ['C1498']
# ['Therapeutic Tumor Infiltrating Lymphocytes'] ['C28699']
# ['Chlorobutanol'] ['C65317']
# ['Adenovirus p53'] ['C2451']
# ['Therapeutic Hydrocortisone'] ['C555']
# ['Saracatinib'] ['C87276']
# ['Magnesium Glycinate'] ['C76082']
# ['Trehalose'] ['C87705']
# ['Tangerine Tomato Juice'] ['C116327']
# ['Somatostatin Antagonist'] ['C154290']
# ['Potassium Saccharin'] ['C95081']
# ['Iobenguane Sulfate I-123'] ['C80095']
# ['Teceleukin'] ['C80836']
# ['Flavin Mononucleotide'] ['C61925']
# ['Methyl Ethyl Ketone'] ['C77477']
# ['Beta-D-Xylopyranose'] ['C77429']
# ['Fermented Soybean Extract'] ['C166174']
# ['Icodextrin'] ['C75647']
# ['Diluent for (161-180)ESO-1 Peptide'] ['C28991']
# ['Folic Acid Derivative'] ['C2078']
# ['E7(86-93) Lipopeptide'] ['C28616']
# ['Chlorogenic Acid'] ['C116073']
# ['Alginic Acid'] ['C82277']
# ['Ginseng/Lingzhi Mushroom/Cordyceps sinensis/Rose Oral Liquid'] ['C156397']
# ['Sterile 0.01N Hydrochloride'] ['C2812']
# ['HIV Peptide Vaccine'] ['C29085']
# ['Fluoroethyltyrosine F18'] ['C62272']
# ['Sevelamer Carbonate'] ['C78122']
# ['Aluminum Phosphate'] ['C80914']
# ['Monoclonal Antibody Bombesin-ITC-D'] ['C42056']
# ['Polyethylene Glycol 3350-Based Laxative'] ['C77958']
# ['Oglufanide Disodium'] ['C74204']
# ['Lexidronam'] ['C90830']
# ['Monoclonal Antibody GW2016'] ['C2716']
# ['Dihydrotachysterol'] ['C87290']
# ['PDGFR Inhibitor'] ['C159199']
# ['Canarypox Vector'] ['C2098']
# ['131 I-Ethiodized Oil'] ['C2093']
# ['Recombinant Macrophage Colony-Stimulating Factor'] ['C1290']
# ['Sodium Ascorbate'] ['C82322']
# ['Tretinoin'] ['C900']
# ['Benzaldehyde'] ['C2591']
# ['Silenafil Citrate'] ['C29452']
# ['Doxorubicin-DNA Complex'] ['C1075']
# ['Recombinant Beta Chemokine'] ['C1591']
# ['Ma Zi Ren Wan'] ['C129581']
# ['Cysteine Hydrochloride Anhydrous'] ['C77372']
# ['Maxacalcitol'] ['C143087']
# ['Irofulven'] ['C1717']
# ['Zinc Oleate'] ['C66693']
# ['Magnesium Aluminum Silicate'] ['C83898']
# ['Gallium Ga 68 Citrate'] ['C121554']
# ['7-Hydroxystaurosporine'] ['C1271']
# ['G17DT Immunogen'] ['C2314']
# ['Tacalcitol'] ['C87292']
# ['Calcium Carbonate'] ['C332']
# ['Vitamin B Complex'] ['C940']
# ['Other Recombinant Chemokine'] ['C1912']
# ['Devils Claw'] ['C39685']
# ['Yang Yin Fang'] ['C129993']
# ['HIV Integrase Inhibitor'] ['C157401']
# ['Olive Oil/Soybean Oil/Multi-amino Acid/Glucose Parenteral Nutrition Emulsion'] ['C118366']
# ['Trolamine'] ['C80948']
# ['Interferon Gamma-1a'] ['C100088']
# ['Lomotrex'] ['C29161']
# ['Recombinant Human Thrombopoietin'] ['C878']
# ['Green Propolis Supplement'] ['C174111']
# ['GI14721'] ['C2518']
# ['Citrate Phosphate Dextrose'] ['C71605']
# ['Antineoplastic Radiopharmaceutical Agent'] ['C129819']
# ['Hydroxocobalamin Acetate'] ['C77156']
# ['Acebutolol'] ['C61525']
# ['sn-1,2-Didecanoylglycerol'] ['C29869']
# ['Tyrosinase Peptide'] ['C2401']
# ['Phenampromide'] ['C66367']
# ['Jambul'] ['C39684']
# ['Alfacalcidol'] ['C80258']
# ['Ferrocholinate'] ['C76836']
# ['Octreotide Pamoate'] ['C2402']
# ...
# ['3-Nitro-3-Methoxyflavone'] ['C63777']
# ['Thiamine Mononitrate'] ['C87669']
# ['Coniine'] ['C87476']
# ['Quercetin'] ['C117288']
# ['HPV-16E7 (86-93)'] ['C2769']
# ['Sodium Feredetate'] ['C76827']
# ['Trans Sodium Crocetinate'] ['C82695']
# ['Pelitrexol'] ['C77586']
# ['Polyvinyl Alcohol (PVA)'] ['C29371']
# ['Therapeutic Growth Hormone'] ['C164163']
# ['Bisoxatin Acetate'] ['C142961']
# ['DN-101'] ['C39714']
# ['Carrot/Jilin Ginseng/Licorice Root/Tangerine Peel/Soy Beverage'] ['C90538']
# ['Ferrous Lactate'] ['C76078']
# ['Inositol'] ['C28163']
# ['Vitamin K2-rich Cheese'] ['C174522']
# ['Vitamin E Acetate'] ['C2834']
# ['Sorbic Acid'] ['C82293']
# ['Bifidobacterium animalis ssp. lactis Probiotic Supplement'] ['C174516']
# ['Sodium Lauryl Sulfate'] ['C76733']
# ['Docetaxel/Ritonavir'] ['C162784']
# ['Botulinum Toxin Type A3'] ['C163593']
# ['Thymidine'] ['C880']
# ['Acetanilide'] ['C76696']
# ['CNS Stimulant'] ['C47795']
# ['Razoxane'] ['C801']
# ['c-RAF Antisense'] ['C1693']
# ['Zinc Gluconate'] ['C84248']
# ['d-Alpha-Tocopherol Acetate'] ['C74962']
# ['Carcinoembryonic Antigen Peptide'] ['C49272']
# ['Pediatric Nutritional Supplement Drink'] ['C84848']
# ['T-1622'] ['C2053']
# ['Recombinant Human IL-4'] ['C2808']
# ['Strontium Sr-82'] ['C80653']
# ['DNA Compaction Peptide'] ['C29717']
# ['CCR4-targeting Agent'] ['C163998']
# ['Therapeutic Gonadotropin'] ['C527']
# ['Deferasirox'] ['C48384']
# ['Glyceryl Trioleate'] ['C77513']
# ['Talinexomer'] ['C152495']
# ['Eflenograstim Alfa'] ['C166591']
# ['Nutritional Supplement Drink'] ['C74452']
# ['3,4-Dinitroflavone'] ['C63944']
# ['Lactobutyrin'] ['C29144']
# ['Antisecretory Factor-enriched Egg Yolk Powder Supplement'] ['C165649']
# ['L-Arginine/American Ginseng/Korean Ginseng/Ginkgo biloba-Based Supplement'] ['C73130']
# ['Cholinergic Agonist'] ['C47796']
# ['Carboxyamidotriazole'] ['C1141']
# ['Fluorescent Imaging Agent cRGD-ZW800-1'] ['C174523']
# ['Commercial or Non-CTEP IND Agent'] ['C38471']
# ['Nicotine Replacement Agent'] ['C168699']
# ['Platelets Product'] ['C133278']
# ['QS21'] ['C1478']
# ['M A B72.3 (CEL)'] ['C29173']
# ['Recombinant Growth Factor'] ['C530']
# ['Kava-based Supplement'] ['C126793']
# ['Intedanib'] ['C95231']
# ['Nanoparticle Paclitaxel Ointment SOR007'] ['C146822']
# ['Incyclinide'] ['C65907']
# ['Lactobacillus plantarum strain 299v'] ['C90549']
# ['Iodine I-131'] ['C87412']
# ['IL-2/Lptn Loaded Allogeneic Neuroblastoma Cell Vaccine'] ['C78818']
# ['PD-1 Ligand Inhibitor'] ['C156893']
# ['2-Chloro-4-Phenylphenol'] ['C61619']
# ['Recoflavone'] ['C152170']
# ['Antimony Potassium Tartrate'] ['C76863']
# ['Beriplast P'] ['C2585']
# ['Iodide I-125'] ['C87411']
# ['p53:264-272 Peptide'] ['C2784']
# ['Enzymatically-hydrolyzed Whey Protein-based Nutritional Supplement'] ['C121644']
# ['Praxadine'] ['C66457']
# ['Ethanol'] ['C216']
# ['Hydroxyethyl Starch'] ['C102744']
# ['Testolactone (Therapeutic)'] ['C861']
# ['Red Blood Cells Product'] ['C133280']
# ['BCR-ABL Inhibitor'] ['C155700']
# ['3-Nitro-3-Chloroflavone'] ['C63775']
# ['Cetyl Palmitate'] ['C77590']
# ['Flutamide'] ['C509']
# ['Epoetin Beta'] ['C26639']
# ['Edatrexate'] ['C958']
# ['Serotonin Antagonist'] ['C66885']
# ['Securinine'] ['C81359']
# ['Acronycine'] ['C28796']
# ['Bushen-Jianpi Decoction'] ['C151930']
# ['Pseudoephedrine Sulfate'] ['C29391']
# ['Sincalide'] ['C47719']
# ['Ro 19-2968'] ['C64173']
# ['Pneumococcal Conjugate Vaccine'] ['C97123']
# ['PR-52'] ['C29330']
# ['BCL-2 Inhibitor'] ['C159200']
# ['Isoxazole Urea'] ['C2738']
# ['Acai Berry Juice'] ['C99901']
# ['Isobutane'] ['C65972']
# ['Hydroxypropyl Methylcellulose D'] ['C29102']
# ['Sulmarin'] ['C74242']
# ['Somatostatin Receptor Agonist'] ['C62799']
# ['Lactobacillus acidophilus/Streptococcus thermophilus/Bifidobacterium lactis/L. rhamnosus/B. longum/B. bifidum-based Probiotic Supplement'] ['C103275']
# ['Phyllanthoside'] ['C29324']
# ['Powdered Cellulose'] ['C84102']
# ['Nutritional Supplement Drink'] ['C84876']
# ['Cathine'] ['C79914']
# ['c-Met-targeting Agent'] ['C164000']
# ['Tumor Necrosis Factor (CET)'] ['C2243']
# ['Desocriptine'] ['C81357']
# ['Targeted Therapy Agent'] ['C163758']
# ['Blueberry Powder Supplement'] ['C98108']
# ['Alphafilcon A'] ['C142914']
# ['Calcium Phosphate, Dibasic, Dihydrate'] ['C79566']
# ['Radioconjugate'] ['C2124']
# ['1B4M-DTPA-conjugated muB3'] ['C2779']
# ['Recombinant Inhibin'] ['C578']
# ['AXL Inhibitor TP-0903', 'ITK Inhibitor'] ['C156794']
# ['Concentrated Lingzhi Mushroom Extract'] ['C165273']
# ['Betaine Hydrochloride'] ['C82301']
# ['Recombinant Interleukin 10'] ['C1320']
# ['Telisotuzumab Vedotin'] ['C152547']
# ['Methoxy Polyethylene Glycol-Epoetin beta'] ['C38687']
# ['Calcium Cyclamate'] ['C77136']
# ['Anti-GD2 Monoclonal Antibody'] ['C155653']
# ['Tyrphostin Compound'] ['C1757']
# ['Cinnamon'] ['C65331']
# ['MDM2 Inhibitor'] ['C162996']
# ['Methyl Nicotinate'] ['C80889']
# ['Rebimastat'] ['C77517']
# ['Zinc Sulfate Anhydrous'] ['C75661']
# ['Therapeutic Insulin'] ['C581']
# ['Reconstituted Oral Solution Dosage Form'] ['C68985']
# ['Magnesium Acetate'] ['C47592']
# ['Theanine'] ['C87348']
# ['Botulinum Toxin Type A1'] ['C163591']
# ['Tilarginine'] ['C90849']
# ['3-Nitro-8-Methoxy-4-Chloroflavone'] ['C63771']
# ['Formaldehyde Solution'] ['C62229']
# ['Adenovirus Vaccine'] ['C49146']
# ['Gramine'] ['C64181']
# ['Pomegranate-Extract Pill'] ['C78864']
# ['Oral Contraceptive'] ['C389']
# ['Potassium Sorbate'] ['C77490']
# ['Toxoid Vaccine'] ['C96398']
# ['Epothilone B Analogue'] ['C2584']
# ['Recombinant Gamma Chemokine'] ['C1712']
# ['Androstenone'] ['C95969']
# ['Iron Isomaltoside 1000'] ['C92584']
# ['Rathyronine'] ['C87252']
# ['Eflapegrastim'] ['C103856']
# ['Isopropyl Alcohol'] ['C602']
# ['Cupric Oxide'] ['C75640']
# ['Lysine Acetate'] ['C66045']
# ['Deferoxamine Mesylate'] ['C417']
# ['Idoxuridine'] ['C563']
# ['Delta-Tocopherol'] ['C63645']
# ['Vitamin A Compound'] ['C938']
# ['Typhoid Vaccine'] ['C96392']
# ['Chondroitin Sulfate (Bovine)'] ['C90851']
# ['Acesulfame Potassium'] ['C76512']
# ['Dihydrotestosterone'] ['C29619']
# ['Calcium Aspartate'] ['C87332']
# ['MUC-1 Peptide Vaccine'] ['C53290']
# ['DL-Phenylalanine'] ['C61713']
# ['Bifidobacterium animalis/Lactobacillus rhamnosus Probiotic Supplement'] ['C129649']
# ['Edetate Tripotassium'] ['C77834']
# ['Glycyrrhizinate Dipotassium'] ['C80931']
# ['Incyclinide'] ['C2454']
# ['BRAF Inhibitor'] ['C155322']
# ['Receptor Tyrosine Kinase ABT-869'] ['C71706']
# ['Eicosapentaenoic Acid-enriched Nutritional Supplement'] ['C120042']
# ['Digitalis'] ['C65385']
# ['Berberine'] ['C83551']
# ['B3/90YB3/111Y-B3'] ['C28847']
# ['Polyethylene Glycol 3350'] ['C80131']
# ['Purple Grape Juice'] ['C90536']
# ['Levomefolate Calcium'] ['C87335']
# ['Aminobenzoate Potassium'] ['C1736']
# ['Beta-Carotene'] ['C1016']
# ['Pegylated Interferon Alfa'] ['C2491']
# ['Antimony Trisulfide'] ['C142927']
# ['Ultra Emu Oil'] ['C73131']
# ['Glucosamine Sulfate/Chondroitin Sulfate Tablet'] ['C77881']
# ['Ginkgo'] ['C29072']
# ['Pentetate Zinc Trisodium'] ['C77835']
# ['Ghrelin Peptide Analogue'] ['C84868']
# ['Carrot Juice'] ['C116739']
# ['U-90'] ['C29527']
# ['Sodium Bisulfite'] ['C73837']
# ['Phenylmercuric Acetate'] ['C84050']
# ['Pituitary Agent'] ['C2348']
# ['Sorbitan Monolaurate'] ['C75653']
# ['Chemokine Receptor Antagonist'] ['C63817']
# ['Saccharin Sodium Anhydrous'] ['C77139']
# ['Magnesium Phosphate, Tribasic, Pentahydrate'] ['C76083']
# ['Polysorbate 40'] ['C81923']
# ['Protamine'] ['C84122']
# ['Cesium Cs-131'] ['C95022']
# ['Histidine Monohydrochloride'] ['C87704']
# ['Peroxisome Proliferator-Activated Receptor Agonist'] ['C154291']
# ['Proteinase 3:PR1 Peptide'] ['C2797']
# ['Edetate Calcium Disodium Anhydrous'] ['C90829']
# ['Pediculicide'] ['C29727']
# ['CXCR4 Inhibitor'] ['C107589']
# ['4-Hydroxybutanoic Acid'] ['C61773']
# ['Polyethylene Glycol 300'] ['C84078']
# ['Deoxythioguanosine'] ['C28978']
# ['Calcium Cyclamate Anhydrous'] ['C81626']
# ['Cocoa Butter'] ['C83637']
# ['Therapeutic Androgen'] ['C243']
# ['Iobenguane'] ['C87757']
# ['Antineoplastic Enzyme Inhibitor'] ['C129825']
# ['Coniine Hydrobromide'] ['C87477']
# ['3-Nitro-2-Methoxyflavone'] ['C63778']
# ['Malathion'] ['C47593']
# ['Magnesium Stearate'] ['C61820']
# ['Potassium Permanganate'] ['C76726']
# ['Ecromeximab'] ['C87495']
# ['Anti-PD-1 Monoclonal Antibody INCMGA0012'] ['C155689']
# ["Dragon's Blood"] ['C74361']
# ['Sodium Biselenite'] ['C87345']
# ['GM-CSF-secreting Lethally Irradiated Tumor Cell Vaccine'] ['C1978']
# ['Frangula purshiana Bark'] ['C28909']
# ['Glyceryl 1,2-Dinitrate'] ['C87318']
# ['c-KIT Inhibitor'] ['C159198']
# ['Magnesium Gluconate'] ['C76081']
# ['PS IL-10'] ['C29335']
# ['Lactitol Monohydrate'] ['C77137']
# ['Multivitamin'] ['C1654']
# ['Tilarginine'] ['C1178']
# ['Demethylating Agent'] ['C132686']
# ['Immutol'] ['C29117']
# ['Orthocresol'] ['C80609']
# ['Deuterium Oxide'] ['C91099']
# ['Spleen'] ['C23366']
# ['4-Iodo-3-Nitrobenzamide'] ['C77388']
# ['Therapeutic Steroid Hormone'] ['C1636']
# ['Oxygen'] ['C722']
# ['1-Aminocyclopentane'] ['C28778']
# ['Prenatal Vitamin'] ['C92860']
# ['Deniluekin'] ['C28977']
# ['Ferric Ferrocyanide'] ['C47532']
# ['Pyridoxamine Phosphate Anhydrous'] ['C81631']
# ['Goat Milk'] ['C72806']
# ['Interleukin-2 Jurkat Derived'] ['C29986']
# ['Glyceryl Monostearate'] ['C80900']
# ['Interleukin-1-beta New Formulation'] ['C29985']
# ['Glycol Dimethacrylate'] ['C61778']
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
desc_not_semtype
# Out:
# {ncit_20.09d.C170323,
#  ncit_20.09d.C166892,
#  ncit_20.09d.C327,
#  ncit_20.09d.C152971,
#  ncit_20.09d.C166688,
#  ncit_20.09d.C166963,
#  ncit_20.09d.C75775,
#  ncit_20.09d.C29200,
#  ncit_20.09d.C147028,
#  ncit_20.09d.C170123,
#  ncit_20.09d.C152620,
#  ncit_20.09d.C169937,
#  ncit_20.09d.C2126,
#  ncit_20.09d.C166691,
#  ncit_20.09d.C171868,
#  ncit_20.09d.C427,
#  ncit_20.09d.C166912,
#  ncit_20.09d.C166484,
#  ncit_20.09d.C70969,
#  ncit_20.09d.C1955,
#  ncit_20.09d.C37450,
#  ncit_20.09d.C166828,
#  ncit_20.09d.C169995,
#  ncit_20.09d.C75776,
#  ncit_20.09d.C29201,
#  ncit_20.09d.C170294,
#  ncit_20.09d.C170316,
#  ncit_20.09d.C170052,
#  ncit_20.09d.C73794,
#  ncit_20.09d.C38679,
#  ncit_20.09d.C169957,
#  ncit_20.09d.C170251,
#  ncit_20.09d.C118877,
#  ncit_20.09d.C166501,
#  ncit_20.09d.C166876,
#  ncit_20.09d.C2007,
#  ncit_20.09d.C364,
#  ncit_20.09d.C166736,
#  ncit_20.09d.C169774,
#  ncit_20.09d.C166485,
#  ncit_20.09d.C39782,
#  ncit_20.09d.C174870,
#  ncit_20.09d.C170007,
